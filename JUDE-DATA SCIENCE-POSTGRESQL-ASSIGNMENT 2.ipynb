# %%
--JUDE-DATA SCIENCE POSTGRESQL ASSIGNMENT 2

--Q1.HOW MANY COUNTRIES HAVE PLAYED IN THE WORLD CUP (5 YEARS)?
WITH

Five_Year_World_Cup AS (
SELECT
    'wc_2002' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
FROM 
     fifa_2002

UNION ALL

SELECT
     'wc_2006' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
FROM 
     fifa_2006

UNION ALL

SELECT
     'wc_2010' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
FROM 
     fifa_2010

UNION ALL
SELECT
    'wc_2014' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
     goals_against,
     goal_difference
FROM 
     fifa_2014

UNION ALL
	
SELECT
    'wc_2018' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
FROM 
     fifa_2018

)

SELECT
	COUNT(DISTINCT team) AS COUNTRIES
FROM
	Five_year_World_Cup;

 
--Q2.GET THE TOTAL GAMES PLAYED,WIN,LOSS,GOALS FOR/AGAINST?

WITH

Five_Year_World_Cup AS (
	
SELECT
     'wc_2002' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	
     fifa_2002

     UNION ALL

SELECT
	
     'wc_2006' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
     fifa_2006

   UNION ALL

SELECT
	
     'wc_2010' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2010

    UNION ALL
	
SELECT
	
     'wc_2014' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2014

  UNION ALL
	
SELECT
     'wc_2018' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
fifa_2018
)

SELECT

	SUM(games_played) AS total_games_played,
	SUM(win) AS total_win,
	SUM(loss) AS total_loss,
	SUM(goals_for) AS total_goals_for,
	SUM(goals_against) AS total_goals_against
	
FROM
    Five_year_World_Cup
;   


--Q3. THE COUNTRY WITH THE HIGHEST AND LOWEST APPEARANCE IN THE LAST FIVE YEARS?

WITH

Five_Year_World_Cup AS (
	
SELECT
     'wc_2002' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	 goals_against,
     goal_difference
	
FROM 
	
     fifa_2002

     UNION ALL

SELECT
	
     'wc_2006' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	fifa_2006

   UNION ALL

SELECT
	
     'wc_2010' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2010

    UNION ALL
	
SELECT
	
     'wc_2014' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2014

  UNION ALL
	
SELECT
     'wc_2018' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2018
)

SELECT 
     team AS Country, 
	COUNT(*) as highest_lowest_appearances
FROM 
   Five_Year_World_Cup
GROUP BY 
   team
HAVING COUNT
(*) = (
SELECT MAX
	(appearances)
FROM 
	(
SELECT COUNT
	(*) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY 
	team
  ) 
AS subquery
)

UNION ALL

SELECT 
    team AS Country, 
COUNT
    (*) as highest_lowest_appearances
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING COUNT
     (*) = (
SELECT MIN
	(appearances)
FROM 
	(
SELECT COUNT
     (*) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY
	team
  )
AS Subquery
)
ORDER BY highest_lowest_appearances DESC
;



--Q4.THE COUNTRY WITH THE HIGHEST AND LOWEST GAMES PLAYED IN THE LAST 5 YEARS?

WITH

Five_Year_World_Cup AS (
	
SELECT
     'wc_2002' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	
     fifa_2002

     UNION ALL

SELECT
	
     'wc_2006' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	fifa_2006

   UNION ALL

SELECT
	
     'wc_2010' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2010

    UNION ALL
	
SELECT
	
     'wc_2014' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2014

  UNION ALL
	
SELECT
     'wc_2018' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2018
)
SELECT 
    team AS Country, 
	MAX(games_played) as highest_lowest_games_played
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
(games_played) = (
SELECT MAX
	(appearances)
FROM 
	(
SELECT MAX
	(games_played) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY 
	team
  ) 
AS subquery
)

UNION ALL

SELECT 
    team AS Country, 
    MIN(games_played) as highest_lowest_games_played
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
     (games_played) = (
SELECT MIN
	(appearances)
FROM 
	(
SELECT MIN
	(games_played) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY
	team
  )
AS Subquery
)
ORDER BY highest_lowest_games_played DESC
;



--Q5.THE COUNTRY WITH THE HIGHEST AND LOWEST GAMES WON IN THE LAST 5 YEARS?

WITH

Five_Year_World_Cup AS (
	
SELECT
     'wc_2002' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	
     fifa_2002

     UNION ALL

SELECT
	
     'wc_2006' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	fifa_2006

   UNION ALL

SELECT
	
     'wc_2010' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2010

    UNION ALL
	
SELECT
	
     'wc_2014' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2014

  UNION ALL
	
SELECT
     'wc_2018' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2018
)

SELECT 
    team AS Country, 
	MAX(games_played) as highest_lowest_won
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
(win) = (
SELECT MAX
	(appearances)
FROM 
	(
SELECT MAX
	(win) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY 
	team
  ) 
AS subquery
)

UNION ALL

SELECT 
    team AS Country, 
MIN(win) as highest_lowest_games_played
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
     (win) = (
SELECT MIN
	(appearances)
FROM 
	(
SELECT MAX
	(win) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY
	team
  )
AS Subquery
)
ORDER BY highest_lowest_won DESC
;




--Q6.THE COUNTRY WITH THE HIGHEST AND  LOWEST GAMES LOST IN THE LAST 5 YEARS?

WITH

Five_Year_World_Cup AS (
	
SELECT
     'wc_2002' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	 goals_against,
     goal_difference
	
FROM 
	
     fifa_2002

     UNION ALL

SELECT
	
     'wc_2006' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	fifa_2006

   UNION ALL

SELECT
	
     'wc_2010' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2010

    UNION ALL
	
SELECT
	
     'wc_2014' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2014

  UNION ALL
	
SELECT
     'wc_2018' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2018
)

SELECT 
    team AS Country, 
	MAX(loss) as highest_lowest_games_lost
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
(loss) = (
SELECT MAX
	(appearances)
FROM 
	(
SELECT MAX
	(loss) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY 
	team
  ) 
AS subquery
)

UNION ALL

SELECT 
    team AS Country, 
MIN(loss) as highest_lowest_games_lost
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
     (loss) = (
SELECT MIN
	(appearances)
FROM 
	(
SELECT MAX
	(loss) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY
	team
  )
AS Subquery
)
ORDER BY highest_lowest_games_lost DESC
;



--Q7.THE COUNTRY WITH THE HIGHEST AND LOWEST GOALS FOR IN THE LAST 5 YEARS?

WITH

Five_Year_World_Cup AS (
	
SELECT
     'wc_2002' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	
     fifa_2002

     UNION ALL

SELECT
	
     'wc_2006' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	fifa_2006

   UNION ALL

SELECT
	
     'wc_2010' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2010

    UNION ALL
	
SELECT
	
     'wc_2014' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2014

  UNION ALL
	
SELECT
     'wc_2018' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2018
)

SELECT 
    team AS Country, 
	MAX(goals_for) as highest_lowest_games_for
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
(goals_for) = (
SELECT MAX
	(appearances)
FROM 
	(
SELECT MAX
	(goals_for) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY 
	team
  ) 
AS subquery
)

UNION ALL

SELECT 
    team AS Country, 
MIN(goals_for) as highest_lowest_games_for
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
     (goals_for) = (
SELECT MIN
	(appearances)
FROM 
	(
SELECT MAX
	(goals_for) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY
	team
  )
AS Subquery
)
ORDER BY highest_lowest_games_for DESC
;



--Q8.THE COUNTRY WITH THE HIGHEST AND LOWEST GOALS AGAINST IN THE LAST 5 YEARS?

WITH

Five_Year_World_Cup AS (
	
SELECT
     'wc_2002' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	
     fifa_2002

     UNION ALL

SELECT
	
     'wc_2006' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	fifa_2006

   UNION ALL

SELECT
	
     'wc_2010' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2010

    UNION ALL
	
SELECT
	
     'wc_2014' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2014

  UNION ALL
	
SELECT
     'wc_2018' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2018
)

SELECT 
    team AS Country, 
	MAX(goals_against) as highest_lowest_games_against
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
(goals_against) = (
SELECT MAX
	(appearances)
FROM 
	(
SELECT MAX
	(goals_against) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY 
	team
  ) 
AS subquery
)

UNION ALL

SELECT 
    team AS Country, 
MIN(goals_against) as highest_lowest_games_against
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
     (goals_against) = (
SELECT MIN
	(appearances)
FROM 
	(
SELECT MAX
	(goals_against) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY
	team
  )
AS Subquery
)
ORDER BY highest_lowest_games_against DESC
;



--Q9.THE COUNTRY WITH THE HIGHEST AND LOWEST GOAL DIFFERENCE IN THE LAST 5 YEARS?

WITH

Five_Year_World_Cup AS (
	
SELECT
     'wc_2002' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	
     fifa_2002

     UNION ALL

SELECT
	
     'wc_2006' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	fifa_2006

   UNION ALL

SELECT
	
     'wc_2010' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2010

    UNION ALL
	
SELECT
	
     'wc_2014' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2014

  UNION ALL
	
SELECT
     'wc_2018' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2018
)
SELECT 
    team AS Country, 
	MAX(goal_difference) as highest_lowest_goal_difference
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
(goal_difference) = (
SELECT MAX
	(appearances)
FROM 
	(
SELECT MAX
	(goal_difference) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY 
	team
  ) 
AS subquery
)

UNION ALL

SELECT 
    team AS Country, 
MIN(goal_difference) as highest_lowest_goal_difference
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
     (goal_difference) = (
SELECT MIN
	(appearances)
FROM 
	(
SELECT MAX
	(goal_difference) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY
	team
  )
AS Subquery
)
ORDER BY highest_lowest_goal_difference DESC
;



--Q10.THE COUNTRY WITH THE HIGHEST AND LOWEST POINTS IN THE LAST 5 YEARS?

WITH

Five_Year_World_Cup AS (
	
SELECT
     'wc_2002' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	
     fifa_2002

     UNION ALL

SELECT
	
     'wc_2006' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
	fifa_2006

   UNION ALL

SELECT
	
     'wc_2010' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2010

    UNION ALL
	
SELECT
	
     'wc_2014' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2014

  UNION ALL
	
SELECT
     'wc_2018' AS Year_of_worldcup,
     team,
     Point,
     games_played,
     win,
     draw,
     loss,
     goals_for,
	goals_against,
     goal_difference
	
FROM 
   fifa_2018
)

SELECT 
    team AS Country, 
	MAX(point) as highest_lowest_point
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
(point) = (
SELECT MAX
	(appearances)
FROM 
	(
SELECT MAX
	(point) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY 
	team
  ) 
AS subquery
)

UNION ALL

SELECT 
    team AS Country, 
MIN(point) as highest_lowest_point
FROM 
   Five_Year_World_Cup
GROUP BY 
     team
HAVING MAX
     (point) = (
SELECT MIN
	(appearances)
FROM 
	(
SELECT MAX
	(point) as appearances
FROM 
	Five_Year_World_Cup
GROUP BY
	team
  )
AS Subquery
)
ORDER BY highest_lowest_point DESC
;
